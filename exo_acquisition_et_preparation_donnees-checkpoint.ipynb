# %% [markdown]
# # PROJET : Acquistion, agrégation et structuration de données

# %% [markdown]
# Le but de cet projet est de construire un conteneur de données qui contiendra des data sets concernant les **1000 films les mieux notés selon [IMDB](https://www.imdb.com/?ref_=nv_home) de 2000 à maintentant**.

# %% [markdown]
# ### Extraction de données

# %% [markdown]
# Tout d'abord nous avons extraire les données dont vous aurez besoin pour répondre à la question posée.Ensuite combiner différentes méthodes pour extraires toutes les sources dont nous avons  besoin, comme par exemple:
# - télécharger des data sets en Open Data à partir de [kaggle](https://www.kaggle.com/datasets)
# - scraper la [page des 250 films les mieux notés d'IMDB](https://www.imdb.com/chart/top/?ref_=nv_mv_250)
# - utiliser des API(s) existantes pour récupérer des informations manquantes

# %% [markdown]
# Affichez dans les cellules ci-dessous les structures de données dans lesquelles vous avez récupéré les informations pertinentes et donner quelques caractéristiques de chacun de ce(s) data set(s) (par exemple taille, valeurs uniques, min , max ...)

# %%
! pip install pandas
# Out:
# Les cellules en cours d’exécution avec c:\Program Files\Python39\python.exe nécessitent le package ipykernel.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Program Files/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Les cellules en cours d’exécution avec c:\Program Files\Python39\python.exe nécessitent le package ipykernel.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Program Files/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
# le premier travail consiste à recuperer toutes les données  que nous voudrions etudier sur le site de IMBD 
# je conserve les données qui sont utiles pour mon etude de data science pour cet exercice . 1
# une fois j'ai listé les données que je souhaite conserver , maintenant il faut penser comment recuperer ces données
# j'ai utilisé deux methodes pour extraire toutes les données dont j'aurai besoin :
# 1-telechargement des datasets libres  à partir de kaggle pour les deux premiers dataframme 
# 2- scrapper les autres informations pour constituer le dataframe 3 qui renvoi les informations concernant les acteurs et les realisateurs listés dans les 2 premieres datasets
# Out:
# Les cellules en cours d’exécution avec c:\Program Files\Python39\python.exe nécessitent le package ipykernel.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Program Files/Python39/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %%
# 1- les methodes utilsées pour  les deux premiers dataframes 
     # Sur  https://www.kaggle.com/ :
    #Nous avons telecharger trois datasets 
     # un dataset avec 1000 films 
df1= pd.read_csv(r"C:\Users\Fnac\Desktop\Exercice acquisition et preparation des données GBE Grace\Files_project\Dataframe/imdb_top_1000.csv" , sep=',', low_memory=False,  encoding='utf8', on_bad_lines='skip')

# %%
df1
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
len(df1)
# Out:
# 1000

# %%
 # premier dataset telechargé contient 1000 lignes 
 # Notre exercice consite sur les films à partir de 2000 donc nous allons supprimer qui contiennent les années avant 2000

# %%
indexNames = df1[(df1["Released_Year"] <'2000')].index
df1.drop(indexNames , inplace=True)

# %%
df1
# Out:
#                                            Poster_Link  \
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 5    https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 8    https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 10   https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 13   https://m.media-amazon.com/images/M/MV5BZGMxZT...
# ..                                                 ...
# 949  https://m.media-amazon.com/images/M/MV5BYjg5ZD...
# 950  https://m.media-amazon.com/images/M/MV5BYWFlY2...
# 951  https://m.media-amazon.com/images/M/MV5BZTI3Yz...
# 953  https://m.media-amazon.com/images/M/MV5BZTM2ZG...
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...
#
#                                           Series_Title Released_Year  \
# 2                                      The Dark Knight          2008
# 5        The Lord of the Rings: The Return of the King          2003
# 8                                            Inception          2010
# ...

# %%
#Apres eliminations des lignes qui continennet  les années inferieures à 2000 il nous restera 486 films donc il faut aller aussi chercher d'autres films pour completer notre dataset1 des 1000 films

# %%
df1.to_csv('d1_486.csv')

# %%
 # la meme methode nous a permi d'avoir des datasets pour copleter les 10192 films mais pour qui contiennent des doublons

# %% [markdown]
# ## Question 2 [5 points]

# %% [markdown]
# ### Filtrage et structuration des données

# %% [markdown]
# Vous allez maintenant filtrer vos données pour vous assurer qu'elles correspondent aux critères fixés dans les consignes et les structures en 3 dataframes distincts:

# %% [markdown]
# #### Dataframe contenant des informations spécifiques au film :

# %% [markdown]
# Ce dataframe doit contenir à minima une colonne renseignant:
#  - le titre du film
#  - l'année de sa sortie en salle
#  - la durée du film (runtime)
#  - son genre
#  - le nom de son réalisateur (director)
#  - la liste des acteurs principaux
#
# Et en bonus d'autres informations comme:
#  - une description du film
#  - une photo de l'affiche du film

# %% [markdown]
# #### Dataframe contenant des informations concernant la popularité du film :

# %% [markdown]
# Ce dataframe doit contenir à minima une colonne renseignant:
#  - le nombre de votes d'utilisateurs pour ce film (échelle de 1 à 10)
#  - la note moyenne des votes reçus (échelle de 1 à 10)
#  - les recettes du film (en millions de $)
#
# Et en bonus d'autres informations comme:
# - la note mediane des votes reçus (échelle de 1 à 10)
# - l'écart type des votes reçus

# %% [markdown]
# #### Dataframe contenant des informations concernant chaque acteur et réalisateur présents dans ces films :

# %% [markdown]
# Ce dataframe doit contenir à minima une colonne renseignant:
# - leur nom
# - leur pays de naissance
# - leur age
# - son/ses métier(s) (a choisir parmi la liste: acteur, realisateur, producteur)
#
# Et en bonus d'autres informations comme:
# - une photo

# %% [markdown]
# ### Réponse 2

# %% [markdown]
# Afficher dans les cellules ci dessous les informations concernant les dataframes

# %%
#Apres avoir fusionner nos dataframes   Nous allons les filter maintenant ces données qu'elles correpondent aux structures des mes  dataframes

# %%
# dataframme 1 :
# maintenant nous allons creer les colonnnes du premier dataframe 1 
#  supprissons de toutes les colonnes qui constituent pas le dataframe 1
       #data1_1192.drop([''], axis=1, inplace=True)
# Renommer les colonnes 
      #data1_1192=data.rename(columns={'': '',})

# %%
dframe1= pd.read_csv(r"C:\Users\Fnac\Desktop\Exercice acquisition et preparation des données GBE Grace\Files_project\Dataframe/Dataframe1_1192.csv" , sep=',', low_memory=False,  encoding='utf8', on_bad_lines='skip')

# %%
dframe1
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0                0           0
# 1                1           1
# 2                2           2
# 3                3           3
# 4                4           4
# ...            ...         ...
# 1187          1187          63
# 1188          1188          64
# 1189          1189          65
# 1190          1190          66
# 1191          1191          67
#
#                                                   Titre Annee_sortie  \
# 0                                       The Dark Knight         2008
# 1         The Lord of the Rings: The Return of the King         2003
# 2                                             Inception         2010
# 3     The Lord of the Rings: The Fellowship of the Ring         2001
# 4                 The Lord of the Rings: The Two Towers         2002
# ...                                                 ...          ...
# 1187                                         Maleficent         2014
# ...

# %%
# dataframme 2 :
#la meme methode que le dataframe 1 (supprimer les colonnes non demandées et renommes les colonnes en fonction du dataframme demandé

# %%
dframe2= pd.read_csv(r"C:\Users\Fnac\Desktop\Exercice acquisition et preparation des données GBE Grace\Files_project\Dataframe/Dataframe2_1192.csv")

# %%
dframe2
# Out:
#       Unnamed: 0                                              Titre  \
# 0              0                                               Hugo
# 1              2                                   Edge of Tomorrow
# 2              3                                    The Jungle Book
# 3              4                                         Inside Out
# 4              5                                                 Up
# ...          ...                                                ...
# 1009        1190  The Chronicles of Narnia: The Lion, the Witch ...
# 1010        1191                                         Maleficent
# 1011        1192                                             WALL·E
# 1012        1193                                        Rush Hour 3
# 1013        1194                               The Legend of Tarzan
#
#       Notes_moyennes  Nombres_votes Recettes_Films
# 0                8.3            7.5    $73,820,094
# ...

# %%
# dataframme 3 :
# cette partie parlera du scrapping 



# j'ai trouvé des informations des acteurs et realisteurs dans plusieurs sites :
 # https://www.ranker.com/list/most-trustworthy-celebrities/celebrity-lists?ref=listed_on&pos=1



#https://www.ranker.com/list/hottest-male-actors-over-40/keshvaralikhani?ref=listed_on&pos=2



#https://www.ranker.com/crowdranked-list/best-actors?ref=listed_on&pos=5



#https://www.ranker.com/list/the-best-actors-working-today/bustermcdermott?ref=listed_on&pos=7



#https://www.ranker.com/crowdranked-list/best-action-stars?ref=listed_on&pos=8



#https://www.ranker.com/crowdranked-list/who-should-be-the-next-james-bond-actor?ref=listed_on&pos=10



#https://www.ranker.com/list/actor-phonebook-list/carly-kiel?ref=listed_on&pos=11



#https://www.ranker.com/list/most-handsome-male-celebrities-2020/calistylie?ref=listed_on&pos=17



#https://www.ranker.com/list/famous-men-youd-want-to-have-a-beer-with/ariel-kana?ref=listed_on&pos=19

# la methode utilisée pour scrapper ces donnees :

#voir les deux fichier pour le scrapping 
#scrape_list_famous_actors_and_actresses
#Scraper_list_actors_actresses (1)

 # voici le dataframe trois obtnus à travers la fusion des plusieurs dataframe obtnus par la methode du scrapping

# %%
dframe3= pd.read_csv(r"C:\Users\Fnac\Desktop\Exercice acquisition et preparation des données GBE Grace\Files_project\Dataframe/dataframe_3_name_films_photo.csv")

# %%
dframe3
# Out:
#       Unnamed: 0                name                                  films  \
# 0              0  Scarlett Johansson                    Lost in Translation
# 1              1        Henry Cavill                           Man of Steel
# 2              2  Katherine McNamara  Shadowhunters: The Mortal Instruments
# 3              3        Sarah Hyland                        Vampire Academy
# 4              4   Daisy Edgar-Jones                          Normal People
# ...          ...                 ...                                    ...
# 9994        9994       Lindsay Lohan                        The Parent Trap
# 9995        9995        Patrick Page                         In the Heights
# 9996        9996   Natascha McElhone                                Solaris
# 9997        9997       James Marsden                              Hairspray
# 9998        9998       Tenoch Huerta         Black Panther: Wakanda Forever
#
#                                                   Photo
# ...

# %% [markdown]
# ## Question 3 [3 points]

# %% [markdown]
# ### Nettoyage des données

# %% [markdown]
# Realisez des opérations de nettoyage des données afin de rendre vos data sets le plus facilement exploitables. Vous réaliserez **a minima** les traitements suivants:
# - vérification et traitement l'homgeneité du type de donnée dans chaque colonne
# - vérification et traitement des doublons
# - vérification et traitement des outliers

# %% [markdown]
# ### Réponse 3

# %%
# Datframme 1 
#Nous allons supprimer les doublons et faire l'homgenité( remplacer les valeurs manquantes )

# %%
dframe1_clean= pd.read_csv(r"C:\Users\Fnac\Desktop\Exercice acquisition et preparation des données GBE Grace\Files_project\Dataframe/Dataframe1_netoyer.csv")

# %%
dframe1_clean
# Out:
#       Unnamed: 0                                              Titre  \
# 0              0                                    The Dark Knight
# 1              1      The Lord of the Rings: The Return of the King
# 2              2                                          Inception
# 3              3  The Lord of the Rings: The Fellowship of the Ring
# 4              4              The Lord of the Rings: The Two Towers
# ...          ...                                                ...
# 1002        1185                                   Star Trek Beyond
# 1003        1186  The Chronicles of Narnia: The Lion, the Witch ...
# 1004        1187                                         Maleficent
# 1005        1189                                        Rush Hour 3
# 1006        1190                               The Legend of Tarzan
#
#      Annee_sortie Duree_Film                       Genre  \
# 0            2008    152 min        Action, Crime, Drama
# ...

# %%
#Apre la suppresion des doublons le dataframe 1 est propre contiennet 1007 films 
# Datframe 2
  #Pour remplacer les valeurs manquantes :
   #trouver la  valeur de la moyenne dans une colonne 
    # utilser  cette valeur pour remplir les valeurs manquantes dans cette colonnes

# %%
dframe2['Notes_moyennes'].median()
# Out:
# 7.5

# %%
# la moyenne etant 7.5 nous allons prendre cette valeur pour remplacer  les notes moyennes manquantes

# %%
dframe2['Notes_moyennes'].fillna(dframe2['Notes_moyennes'].mode().iloc[0], inplace=True)

# %%
 #supprimer le premier caratere $ des elements de la colone recettes_films

# %%
dframe2["Recettes_Films"].str[1:]
# Out:
# 0        73,820,094
# 1        77,121,429
# 2       363,995,937
# 3       264,317,903
# 4       292,979,556
#            ...
# 1009    291,685,219
# 1010    190,871,149
# 1011    223,749,872
# 1012    140,080,850
# 1013    126,585,313
# Name: Recettes_Films, Length: 1014, dtype: object

# %%
dframe2["Recettes_Films"]=dframe2["Recettes_Films"].str[1:]

# %%
#  supprimer ces %^%^%^ dans les recettes_films
#%^%^%^ comme ces valeurs sont  des chaines de caractere, cela rendait impossible le calcul  de la mediane pour les recettes des films
#pour le faire ces données sont remplacées par zeros

# %%
dframe2.replace('^%^%^',0,inplace=True)

# %%
#median=data2_1196["Recettes_Films"].median() la requette genere des erreur car elle arrive pas a convertir 
#les colonnes string en float 
# d'apres nos calcul on remplace les valeurs manquantes des recettes_films par 19 millions

# %%
dframe2['Recettes_Films'].fillna(19000000, inplace=True)

# %%
dframe2.to_csv('daframe2.csv')

# %%
#traitement des outliers

# %%
# suppressions des unitées
dframe1_clean['Duree_Film']=dframe1_clean['Duree_Film'].str.extract('(\d+)')

# %%
dframe1_clean['Duree_Film']=pd.to_numeric(dframe1_clean['Duree_Film'],errors = 'coerce')

# %%
dframe1_clean
# Out:
#       Unnamed: 0                                              Titre  \
# 0              0                                    The Dark Knight
# 1              1      The Lord of the Rings: The Return of the King
# 2              2                                          Inception
# 3              3  The Lord of the Rings: The Fellowship of the Ring
# 4              4              The Lord of the Rings: The Two Towers
# ...          ...                                                ...
# 1002        1185                                   Star Trek Beyond
# 1003        1186  The Chronicles of Narnia: The Lion, the Witch ...
# 1004        1187                                         Maleficent
# 1005        1189                                        Rush Hour 3
# 1006        1190                               The Legend of Tarzan
#
#      Annee_sortie  Duree_Film                       Genre  \
# 0            2008       152.0        Action, Crime, Drama
# ...

# %%
import seaborn as sns
sns.boxplot(dframe1_clean['Duree_Film'])
# Out:
# C:\Users\Fnac\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Duree_Film'>

# %%
"""Sur cet Box nous remarquons que nous avons 3 outliers, 2 dont les minutes sont inferieures à 50 minutes et une dont la minute est supérieure à 300
Pour plus d'assurance, nous avons verifier sur le site officiel d'imbd et oui les nombres de minutes corresponde parfaitement
"""
# Out:
# "Sur cet Box nous remarquons que nous avons 3 outliers, 2 dont les minutes sont inferieures à 50 minutes et une dont la minute est supérieure à 300\nPour plus d'assurance, nous avons verifier sur le site officiel d'imbd et oui les nombres de minutes corresponde parfaitement\n"

# %%
# utilser les memes methodes que le dataframe 1 et 2 pour les données du dataframe 3

# %%
dframe3= pd.read_csv(r"C:\Users\Fnac\Desktop\Exercice acquisition et preparation des données GBE Grace\Files_project\Dataframe/dataframe3.csv")

# %%
dframe3
# Out:
#       Unnamed: 0              Noms         Metiers  \
# 0              0         Tom Hanks  Acteur/Actrice
# 1              7      Hugh Jackman  Acteur/Actrice
# 2             10   Chris Hemsworth  Acteur/Actrice
# 3             12   Patrick Stewart  Acteur/Actrice
# 4             13      Ian McKellen  Acteur/Actrice
# ...          ...               ...             ...
# 1927         480      Alakina Mann  Acteur/Actrice
# 1928         481  Rachel Griffiths  Acteur/Actrice
# 1929         482      Rachel Weisz  Acteur/Actrice
# 1930         483     Max von Sydow  Acteur/Actrice
# 1931         484         Bill Sage  Acteur/Actrice
#
#                                                   Image  \
# 0     https://imgix.ranker.com/user_node_img/113/225...
# 1     https://imgix.ranker.com/node_img/494/9865656/...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...

# %%
dframe3= dframe3.fillna(" ") # ça permettra de remplaçer toutes les NAN par des chaines de caracteres vides

# %%
dframe3
# Out:
#       Unnamed: 0              Noms         Metiers  \
# 0              0         Tom Hanks  Acteur/Actrice
# 1              7      Hugh Jackman  Acteur/Actrice
# 2             10   Chris Hemsworth  Acteur/Actrice
# 3             12   Patrick Stewart  Acteur/Actrice
# 4             13      Ian McKellen  Acteur/Actrice
# ...          ...               ...             ...
# 1927         480      Alakina Mann  Acteur/Actrice
# 1928         481  Rachel Griffiths  Acteur/Actrice
# 1929         482      Rachel Weisz  Acteur/Actrice
# 1930         483     Max von Sydow  Acteur/Actrice
# 1931         484         Bill Sage  Acteur/Actrice
#
#                                                   Image  \
# 0     https://imgix.ranker.com/user_node_img/113/225...
# 1     https://imgix.ranker.com/node_img/494/9865656/...
# 2
# 3
# 4
# ...                                                 ...
# 1927
# 1928
# 1929
# 1930
# 1931
#
#                                              country               age
# ...

# %%
# j'ai separer le dataframe 3 en deux dataframe :

# %%
 # 1er data contient les images 
 # 2eme contient les nom ,le metier ,pays de naissance et l'age des acteurs et realisateurs

# %%
dframe3_image= pd.read_csv(r"C:\Users\Fnac\Desktop\Exercice acquisition et preparation des données GBE Grace\Files_project\Dataframe/dataframe_images.csv")
dframe3_autres_types_donnees= pd.read_csv(r"C:\Users\Fnac\Desktop\Exercice acquisition et preparation des données GBE Grace\Files_project\Dataframe/dataframe3_autres_types_donnees.csv")

# %%
dframe3_image
# Out:
#       Unnamed: 0                                              Image
# 0              0  https://imgix.ranker.com/user_node_img/113/225...
# 1              7  https://imgix.ranker.com/node_img/494/9865656/...
# 2             10
# 3             12
# 4             13
# ...          ...                                                ...
# 1927         480
# 1928         481
# 1929         482
# 1930         483
# 1931         484
#
# [1932 rows x 2 columns]

# %%
dframe3_autres_types_donnees
# Out:
#       Unnamed: 0              Noms         Metiers  \
# 0              0         Tom Hanks  Acteur/Actrice
# 1              7      Hugh Jackman  Acteur/Actrice
# 2             10   Chris Hemsworth  Acteur/Actrice
# 3             12   Patrick Stewart  Acteur/Actrice
# 4             13      Ian McKellen  Acteur/Actrice
# ...          ...               ...             ...
# 1927         480      Alakina Mann  Acteur/Actrice
# 1928         481  Rachel Griffiths  Acteur/Actrice
# 1929         482      Rachel Weisz  Acteur/Actrice
# 1930         483     Max von Sydow  Acteur/Actrice
# 1931         484         Bill Sage  Acteur/Actrice
#
#                                              country               age
# 0               Birthplace: Concord, California, USA  Born: 07-09-1956
# 1     Birthplace: Sydney, New South Wales, Australia  Born: 10-12-1968
# 2                   Birthplace: Melbourne, Australia  Born: 08-11-1983
# ...

# %% [markdown]
# ## Question 4 [3 points]

# %% [markdown]
# ### Agrégation et structuration des données

# %% [markdown]
# Vos données étant nettoyées, vous allez maintenant les structurez et les stocker dans un **conteneur de données au format HDF5**. Vous êtes libre d'architecturer votre conteneur comme vous le souhaitez créerez a minima deux groupes:
# - un groupe contenant les images que vous allez acquérir
# - un groupe pour tous les autres types de données

# %% [markdown]
# ### Réponse 4

# %% [markdown]
# Affichez à minima, des informations concernant chaque groupe ainsi que les data sets qu'ils contient

# %%
"""Nous allons faire nos groupes  
    1- le groupe du dataframes 1 
    2- le groupe du dataframes 2
    3 -le groupe des images 
    4 un le groupe qui doit contenir le nom,le pays de naissance, ainsi les metiers 
"""
# Out:
# 'Nous allons faire nos groupes  \n    1- le groupe du dataframes 1 \n    2- le groupe du dataframes 2\n    3 -le groupe des images \n    4 un le groupe qui doit contenir le nom,le pays de naissance, ainsi les metiers \n'

# %%
store_films = pd.HDFStore("store.h5") # on cree un store vide

# %%
store_films # affichage du store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: store.h5

# %%
dataframe_1=pd.read_csv(r"C:\Users\Fnac\Desktop\Exercice acquisition et preparation des données GBE Grace\Files_project\Dataframe/Dataframe1_netoyer.csv")
dataframe_2=pd.read_csv(r"C:\Users\Fnac\Desktop\Exercice acquisition et preparation des données GBE Grace\Files_project\Dataframe/daframe2.csv")
dframe3_image= pd.read_csv(r"C:\Users\Fnac\Desktop\Exercice acquisition et preparation des données GBE Grace\Files_project\Dataframe/dataframe_images.csv")
dframe3_autres_typ= pd.read_csv(r"C:\Users\Fnac\Desktop\Exercice acquisition et preparation des données GBE Grace\Files_project\Dataframe/dataframe3_autres_types_donnees.csv")
#dataframe3_donnees

store_films["dataframe_1"]=dataframe_1;
store_films["dataframe_2"]=dataframe_2;
store_films["dframe3_image"] = dframe3_image ;
store_films["dframe3_autres"]=dframe3_autres_typ;

#store_films["dataframe3_donnees"]=dataframe3_donnees;
#store_films["dataframe_image"]=dataframe_image;
# Out:
# C:\Users\Fnac\AppData\Local\Temp\ipykernel_39492\468355591.py:7: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['Titre', 'Annee_sortie', 'Duree_Film', 'Genre', 'Description',
#        'Realisateur', 'Acteurs_principaux'],
#       dtype='object')]
#
#   store_films["dataframe_1"]=dataframe_1;

# %%
store_films.groups()
# Out:
# [/dataframe_1 (Group) ''
#    children := ['axis0' (Array), 'axis1' (Array), 'block0_values' (Array), 'block0_items' (Array), 'block1_values' (VLArray), 'block1_items' (Array)],
#  /dataframe_2 (Group) ''
#    children := ['axis0' (Array), 'axis1' (Array), 'block0_values' (Array), 'block0_items' (Array), 'block1_values' (Array), 'block1_items' (Array), 'block2_values' (VLArray), 'block2_items' (Array)],
#  /dataframme_1 (Group) ''
#    children := ['axis0' (Array), 'axis1' (Array), 'block0_items' (Array), 'block0_values' (Array), 'block1_items' (Array), 'block1_values' (VLArray)],
#  /dataframme_2 (Group) ''
#    children := ['axis0' (Array), 'axis1' (Array), 'block0_items' (Array), 'block0_values' (Array), 'block1_items' (Array), 'block1_values' (Array), 'block2_items' (Array), 'block2_values' (VLArray)],
#  /dframe3_autres (Group) ''
# ...

# %%
store_films.close()

# %% [markdown]
# ## Question 5 [6 points] (2 points sont en bonus)

# %% [markdown]
# ### Exploitation de vos données

# %% [markdown]
# A partir de votre conteneur HDF5 vous allez extraire, filtrer et agréger vos données pour répondre aux questions suivantes:
# - Quelle est la durée médiane des films ? (1 points)
# - Quels sont les notes moyennes des films par genre ? (1.5 points)
# - Faites un graphique pour représenter la répartition des durées des films (1.5 points)
# - Quels sont les caractéristiques des acteurs et réalisateurs ayant participé aux 5% des films les mieux notés ? (2 points)

# %% [markdown]
# ### Réponse 5

# %%
#Pour la durée mediane  du film nous allons utiliser le groupe 1

# %%
median=dframe1_clean["Duree_Film"].median()

# %%
median
# Out:
# 115.0

# %%
#un graphique pour représenter la répartition des durées des films

# %%
plt.hist(data_sorted['Duree_Film'], 10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39492\813613859.py in <module>
# ----> 1 plt.hist(data_sorted['Duree_Film'], 10)
#       2 plt.show()
#
# NameError: name 'data_sorted' is not defined

# %%
#les notes moyennes des films par genre

# %%
df2= pd.read_csv(r"C:\Users\Windows10\Desktop\exercice_classe/daframe2.csv")

# %%
df2
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0                0           0
# 1                1           2
# 2                2           3
# 3                3           4
# 4                4           5
# ...            ...         ...
# 1009          1009        1190
# 1010          1010        1191
# 1011          1011        1192
# 1012          1012        1193
# 1013          1013        1194
#
#                                                   Titre  Notes_moyennes  \
# 0                                                  Hugo             8.3
# 1                                      Edge of Tomorrow             7.1
# 2                                       The Jungle Book             7.7
# 3                                            Inside Out             9.4
# 4                                                    Up             8.8
# ...                                                 ...             ...
# 1009  The Chronicles of Narnia: The Lion, the Witch ...             7.5
# ...

# %%
#Dataframme avec le genre et la note 
frame=[d1["Genre"],df2["Notes_moyennes"]]
df4=pd.concat(frame)
df4.head()
# Out:
# 0         Action, Crime, Drama
# 1     Action, Adventure, Drama
# 2    Action, Adventure, Sci-Fi
# 3     Action, Adventure, Drama
# 4     Action, Adventure, Drama
# dtype: object

# %%
d1.head(10)
# Out:
#    Unnamed: 0                                              Titre Annee_sortie  \
# 0           0                                    The Dark Knight         2008
# 1           1      The Lord of the Rings: The Return of the King         2003
# 2           2                                          Inception         2010
# 3           3  The Lord of the Rings: The Fellowship of the Ring         2001
# 4           4              The Lord of the Rings: The Two Towers         2002
# 5           5                                           Hamilton         2020
# 6           6                                       Gisaengchung         2019
# 7           7                                    Soorarai Pottru         2020
# 8           8                                       Interstellar         2014
# 9           9                                     Cidade de Deus         2002
#
#    Duree_Film                      Genre  \
# 0       152.0       Action, Crime, Drama
# ...

# %%
df2["Notes_moyennes"]
# Out:
# 0       8.3
# 1       7.1
# 2       7.7
# 3       9.4
# 4       8.8
#        ...
# 1009    7.5
# 1010    5.6
# 1011    9.4
# 1012    4.4
# 1013    4.4
# Name: Notes_moyennes, Length: 1014, dtype: float64

# %%
df1
# Out:
#       Unnamed: 0                                              Titre  \
# 0              0                                    The Dark Knight
# 1              1      The Lord of the Rings: The Return of the King
# 2              2                                          Inception
# 3              3  The Lord of the Rings: The Fellowship of the Ring
# 4              4              The Lord of the Rings: The Two Towers
# ...          ...                                                ...
# 1002        1185                                   Star Trek Beyond
# 1003        1186  The Chronicles of Narnia: The Lion, the Witch ...
# 1004        1187                                         Maleficent
# 1005        1189                                        Rush Hour 3
# 1006        1190                               The Legend of Tarzan
#
#      Annee_sortie  Duree_Film                       Genre  \
# 0            2008       152.0        Action, Crime, Drama
# ...

# %%
 # les caractéristiques des acteurs et réalisateurs ayant participé aux 5% des films les mieux notés ? (2 points)

# %%
# pour repondre à cete questions nous allons utilser le dataframe 2

# %%
df2= pd.read_csv(r"C:\Users\Windows10\Desktop\exercice_classe/daframe2.csv")

# %%
df2
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 0                0           0
# 1                1           2
# 2                2           3
# 3                3           4
# 4                4           5
# ...            ...         ...
# 1009          1009        1190
# 1010          1010        1191
# 1011          1011        1192
# 1012          1012        1193
# 1013          1013        1194
#
#                                                   Titre  Notes_moyennes  \
# 0                                                  Hugo             8.3
# 1                                      Edge of Tomorrow             7.1
# 2                                       The Jungle Book             7.7
# 3                                            Inside Out             9.4
# 4                                                    Up             8.8
# ...                                                 ...             ...
# 1009  The Chronicles of Narnia: The Lion, the Witch ...             7.5
# ...

# %%
 #j'affiche les films les mieux notés 
   # je fais le tri des meilleurs films qui sont au dessus de la moyenne et afficher 5 % de ces films

# %%
print(df2.sort_values(by=['Notes_moyennes']))
# Out:
#      Unnamed: 0.1  Unnamed: 0                         Titre  Notes_moyennes  \
# 506           506         511                Brotherly Love             0.0
# 574           574         580                   Now Is Good             0.0
# 573           573         579                   Crazy Stone             0.0
# 565           565         571             Faith Connections             0.0
# 564           564         570                   Starsuckers             0.0
# ..            ...         ...                           ...             ...
# 17             17          18                   Ratatouille             9.6
# 876           876         984                          Roma             9.6
# 551           551         557  4 Months, 3 Weeks and 2 Days             9.7
# 253           253         255               Pan's Labyrinth             9.8
# 444           444         449                       Boyhood            10.0
#
#      Nombres_votes Recettes_Films
# ...

# %%
d2=df2.nlargest(50, 'Notes_moyennes')

# %%
print(d2.shape)
# Out:
# (50, 6)
